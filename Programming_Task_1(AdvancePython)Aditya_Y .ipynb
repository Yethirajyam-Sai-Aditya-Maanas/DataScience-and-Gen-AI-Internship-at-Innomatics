# %%
from typing import List

class Solution:
    def runningSum(self, nums: List[int]) -> List[int]:
        for i in range(1, len(nums)):
            nums[i] = nums[i-1] + nums[i]
        return nums
sol1 = Solution()
print("Running Sum Output:", sol1.runningSum([1, 2, 3, 4]))
# Out:
# Running Sum Output: [1, 3, 6, 10]

# %%
class Solution:
    def shuffle(self, nums: List[int], n: int) -> List[int]:
        res = []
        for i in range(n):
            res.append(nums[i])
            res.append(nums[i+n])
        return res

# ---- ADDED: run shuffle (1st time) ----
sol2 = Solution()
print("Shuffle Output 1:", sol2.shuffle([2, 5, 1, 3, 4, 7], 3))
# Out:
# Shuffle Output 1: [2, 3, 5, 4, 1, 7]

# %%
class Solution:
    def kidsWithCandies(self, candies: List[int], extraCandies: int) -> List[bool]:
        Maxcandies = max(candies)
        result = []
        for i in candies:
            if i+extraCandies >= Maxcandies:
                result.append(True)
            else:
                result.append(False)

        return result
sol = Solution()
candies = [2, 3, 5, 1, 3]
extraCandies = 3
print(sol.kidsWithCandies(candies, extraCandies))
# Out:
# [True, True, True, False, True]
